# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
url = "https://uk.wikipedia.org/wiki/%D0%9D%D0%B0%D1%80%D0%BE%D0%B4%D0%B6%D1%83%D0%B2%D0%B0%D0%BD%D1%96%D1%81%D1%82%D1%8C_%D0%B2_%D0%A3%D0%BA%D1%80%D0%B0%D1%97%D0%BD%D1%96"

# %%
tmp = pd.read_html(url)

# %%
# print(tmp[20])
table = tmp[20]

# %% [markdown]
# Вивести перші рядки таблиці за допомогою методу head

# %%
table.head()
# Out:
#                       регіон   1950   1960   1970  1990  1992  1994  1996  \
# 0  Автономна Республіка Крим  230.0  206.0  160.0   130   109    93    80
# 1          Вінницька область  224.0  192.0  142.0   124   119   107   103
# 2          Волинська область  247.0  250.0  179.0   153   150   137   125
# 3   Дніпропетровська область  204.0  204.0  151.0   123   106    92    80
# 4           Донецька область  271.0  214.0  140.0   109    94    82    70
#
#    2000  2004  2008  2012   2014
# 0    73    90   119   126    NaN
# 1    84    90   108   112  109.0
# 2   112   119   148   148  141.0
# 3    71    89   110   112  111.0
# 4    61    76    98    98   82.0

# %% [markdown]
# Визначте кількість рядків та стовпців у датафреймі (атрибут shape)

# %%
table.shape
# Out:
# (28, 13)

# %% [markdown]
# Замініть у таблиці значення "—" на значення NaN

# %%
table =  table.replace("—", np.nan)

# %%
table
# Out:
#                        регіон   1950   1960   1970  1990  1992  1994  1996  \
# 0   Автономна Республіка Крим  230.0  206.0  160.0   130   109    93    80
# 1           Вінницька область  224.0  192.0  142.0   124   119   107   103
# 2           Волинська область  247.0  250.0  179.0   153   150   137   125
# 3    Дніпропетровська область  204.0  204.0  151.0   123   106    92    80
# 4            Донецька область  271.0  214.0  140.0   109    94    82    70
# 5         Житомирська область  261.0  223.0  159.0   129   128   118   108
# 6        Закарпатська область  314.0  273.0  207.0   168   161   138   128
# 7          Запорізька область  219.0  197.0  150.0   124   107    92    81
# 8   Івано-Франківська область  243.0  248.0  182.0   155   144   131   122
# 9            Київська область  204.0  189.0  156.0   123   111    99    92
# 10     Кіровоградська область  216.0  171.0  145.0   126   119   107    96
# ...

# %% [markdown]
# Визначте типи всіх стовпців за допомогою dataframe.dtypes

# %%
table.dtypes
# Out:
# регіон     object
# 1950      float64
# 1960      float64
# 1970      float64
# 1990        int64
# 1992        int64
# 1994        int64
# 1996        int64
# 2000        int64
# 2004        int64
# 2008        int64
# 2012        int64
# 2014      float64
# dtype: object

# %% [markdown]
# Замініть типи нечислових колонок на числові. Підказка - це колонки, де знаходився символ "—"

# %%
for column in table.columns:
#     print(table[column])
    if column not in "регіон":
        table[column] = table[column].astype(np.float64)
#         table[column]
        
table.dtypes
# Out:
# регіон     object
# 1950      float64
# 1960      float64
# 1970      float64
# 1990      float64
# 1992      float64
# 1994      float64
# 1996      float64
# 2000      float64
# 2004      float64
# 2008      float64
# 2012      float64
# 2014      float64
# dtype: object

# %%
table
# Out:
#                        регіон   1950   1960   1970   1990   1992   1994  \
# 0   Автономна Республіка Крим  230.0  206.0  160.0  130.0  109.0   93.0
# 1           Вінницька область  224.0  192.0  142.0  124.0  119.0  107.0
# 2           Волинська область  247.0  250.0  179.0  153.0  150.0  137.0
# 3    Дніпропетровська область  204.0  204.0  151.0  123.0  106.0   92.0
# 4            Донецька область  271.0  214.0  140.0  109.0   94.0   82.0
# 5         Житомирська область  261.0  223.0  159.0  129.0  128.0  118.0
# 6        Закарпатська область  314.0  273.0  207.0  168.0  161.0  138.0
# 7          Запорізька область  219.0  197.0  150.0  124.0  107.0   92.0
# 8   Івано-Франківська область  243.0  248.0  182.0  155.0  144.0  131.0
# 9            Київська область  204.0  189.0  156.0  123.0  111.0   99.0
# 10     Кіровоградська область  216.0  171.0  145.0  126.0  119.0  107.0
# 11          Луганська область  262.0  235.0  144.0  116.0  101.0   84.0
# ...

# %% [markdown]
# Порахуйте, яка частка пропусків міститься в кожній колонці (використовуйте методи isnull та sum)

# %%
print(table.isnull().sum())
# Out:
# регіон    0
# 1950      2
# 1960      1
# 1970      1
# 1990      0
# 1992      0
# 1994      0
# 1996      0
# 2000      0
# 2004      0
# 2008      0
# 2012      0
# 2014      2
# dtype: int64

# %% [markdown]
# Видаліть з таблиці дані по всій країні, останній рядок таблиці

# %%
table = table.drop(table.index[-1])
table
# Out:
#                        регіон   1950   1960   1970   1990   1992   1994  \
# 0   Автономна Республіка Крим  230.0  206.0  160.0  130.0  109.0   93.0
# 1           Вінницька область  224.0  192.0  142.0  124.0  119.0  107.0
# 2           Волинська область  247.0  250.0  179.0  153.0  150.0  137.0
# 3    Дніпропетровська область  204.0  204.0  151.0  123.0  106.0   92.0
# 4            Донецька область  271.0  214.0  140.0  109.0   94.0   82.0
# 5         Житомирська область  261.0  223.0  159.0  129.0  128.0  118.0
# 6        Закарпатська область  314.0  273.0  207.0  168.0  161.0  138.0
# 7          Запорізька область  219.0  197.0  150.0  124.0  107.0   92.0
# 8   Івано-Франківська область  243.0  248.0  182.0  155.0  144.0  131.0
# 9            Київська область  204.0  189.0  156.0  123.0  111.0   99.0
# 10     Кіровоградська область  216.0  171.0  145.0  126.0  119.0  107.0
# 11          Луганська область  262.0  235.0  144.0  116.0  101.0   84.0
# ...

# %% [markdown]
# Замініть відсутні дані в стовпцях середніми значеннями цих стовпців (метод fillna)

# %%
table = table.fillna({i: table[i].mean() for i in table if i != 'регіон'})
table
# Out:
#                        регіон    1950        1960   1970   1990   1992   1994  \
# 0   Автономна Республіка Крим  230.00  206.000000  160.0  130.0  109.0   93.0
# 1           Вінницька область  224.00  192.000000  142.0  124.0  119.0  107.0
# 2           Волинська область  247.00  250.000000  179.0  153.0  150.0  137.0
# 3    Дніпропетровська область  204.00  204.000000  151.0  123.0  106.0   92.0
# 4            Донецька область  271.00  214.000000  140.0  109.0   94.0   82.0
# 5         Житомирська область  261.00  223.000000  159.0  129.0  128.0  118.0
# 6        Закарпатська область  314.00  273.000000  207.0  168.0  161.0  138.0
# 7          Запорізька область  219.00  197.000000  150.0  124.0  107.0   92.0
# 8   Івано-Франківська область  243.00  248.000000  182.0  155.0  144.0  131.0
# 9            Київська область  204.00  189.000000  156.0  123.0  111.0   99.0
# 10     Кіровоградська область  216.00  171.000000  145.0  126.0  119.0  107.0
# ...

# %%
plt.barh(table['регіон'], table['2014'])
plt.xlabel("Коефіцієнт", fontsize="small", color="midnightblue")
plt.ylabel("Регіон", fontsize="small", color="midnightblue")
plt.title("Коефіцієнт народжуваності у регіонах України у 2014р (народжень на 1000 осіб, ‰)", fontsize=15)
plt.show()

# %% [markdown]
# Отримайте список регіонів, де рівень народжуваності у 2019 році був вищим за середній по Україні
#
# виконав для 2014 року так як за 2019 данних в мене не було в таблиці.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
average_bd = table["2014"].mean()
average_bd
# Out:
# 111.44

# %%
average_table_bd = table[table['2014'] > average_bd][['регіон', '2014']]
average_table_bd
# Out:
#                        регіон   2014
# 2           Волинська область  141.0
# 5         Житомирська область  120.0
# 6        Закарпатська область  146.0
# 8   Івано-Франківська область  122.0
# 9            Київська область  121.0
# 12          Львівська область  119.0
# 13       Миколаївська область  112.0
# 14            Одеська область  123.0
# 16         Рівненська область  148.0
# 20         Херсонська область  115.0
# 21        Хмельницька область  112.0
# 23        Чернівецька область  129.0
# 25                       Київ  121.0

# %%
plt.pie(
    average_table_bd['2014'],
    labels=average_table_bd['регіон'],
    shadow=True,
    autopct="%.2f%%",
    pctdistance=1.15,
    labeldistance=1.35,
)

plt.show()

# %% [markdown]
# У якому регіоні була найвища народжуваність у 2014 році?

# %%
average_bd_max_1_2014 = table["2014"].max()
average_bd_max_1_2014
# Out:
# 148.0

# %%
average_bd_max_1_2014 = table[table['2014'] == table["2014"].max()][['регіон', '2014']]
average_bd_max_1_2014
# Out:
#                 регіон   2014
# 16  Рівненська область  148.0

# %% [markdown]
# Побудуйте стовпчикову діаграму народжуваності по регіонах у 2019 році
#
# відповідно діаграма на 2014 рік тому що данні за 2019 рік відсутні.

# %%
y = table['2014']
x = table['регіон']
plt.bar(x, y, label="2014")
plt.xlabel('Регіони')
plt.xticks(rotation=90)
plt.ylabel('Коефіцієнт народжуваності')
plt.legend()
plt.show()
