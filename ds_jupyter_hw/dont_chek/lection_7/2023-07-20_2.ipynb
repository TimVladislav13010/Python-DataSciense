# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("/kaggle/input/spotify-recommendation/data.csv")

# %%
df = df.drop(["time_signature", "liked"], axis=1)

# %%
df
# Out:
#      danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0           0.803  0.6240    7    -6.764     0       0.0477        0.4510
# 1           0.762  0.7030   10    -7.951     0       0.3060        0.2060
# 2           0.261  0.0149    1   -27.528     1       0.0419        0.9920
# 3           0.722  0.7360    3    -6.994     0       0.0585        0.4310
# 4           0.787  0.5720    1    -7.516     1       0.2220        0.1450
# ..            ...     ...  ...       ...   ...          ...           ...
# 190         0.166  0.0551    9   -19.494     0       0.0520        0.9760
# 191         0.862  0.6240    3   -11.630     1       0.0565        0.0192
# 192         0.499  0.3510    9   -11.509     0       0.0448        0.9510
# 193         0.574  0.7290   10    -5.838     0       0.0965        0.0406
# 194         0.747  0.6660   11    -7.845     1       0.1970        0.1300
#
#      instrumentalness  liveness  valence    tempo  duration_ms
# ...

# %%
norm_df = (df - df.min()) / (df.max() - df.min())

# %%
norm_df
# Out:
#      danceability    energy       key  loudness  mode  speechiness  \
# 0        0.824755  0.625604  0.636364  0.889092   0.0     0.038852
# 1        0.774510  0.705113  0.909091  0.859361   0.0     0.543147
# 2        0.160539  0.012581  0.090909  0.369017   1.0     0.027528
# 3        0.725490  0.738325  0.272727  0.883331   0.0     0.059938
# 4        0.805147  0.573269  0.090909  0.870257   1.0     0.379149
# ..            ...       ...       ...       ...   ...          ...
# 190      0.044118  0.053039  0.818182  0.570244   0.0     0.047247
# 191      0.897059  0.625604  0.272727  0.767214   1.0     0.056033
# 192      0.452206  0.350845  0.818182  0.770244   0.0     0.033190
# 193      0.544118  0.731280  0.909091  0.912286   0.0     0.134127
# 194      0.756127  0.667874  1.000000  0.862016   1.0     0.330340
#
#      acousticness  instrumentalness  liveness   valence     tempo  duration_ms
# 0        0.453265          0.000757  0.111519  0.627395  0.298644     0.393282
# ...

# %%
sample = {
    'danceability': 0.561,
 'energy': 0.9149,
 'key': 1.0,
 'loudness': 50.528,
 'mode': 1.0,
 'speechiness': 0.0419,
 'acousticness': 0.992,
 'instrumentalness': 0.897,
 'liveness': 0.902,
 'valence': 0.6382,
 'tempo': 75.296,
 'duration_ms': 286987.0}

# %%
sample_series = pd.Series(sample)

# %%
norm_sample_series = (sample_series - df.min()) / (df.max() - df.min())

# %%
recs = np.sqrt(np.sum((norm_df - norm_sample_series) ** 2, axis=1))

# %%
recs
# Out:
# 0      2.549454
# 1      2.813810
# 2      2.638118
# 3      2.465523
# 4      2.528210
#          ...
# 190    2.893789
# 191    2.601291
# 192    2.619617
# 193    2.654167
# 194    2.375606
# Length: 195, dtype: float64

# %%
recs.sort_values().index[:5]
# Out:
# Int64Index([115, 37, 157, 34, 12], dtype='int64')
